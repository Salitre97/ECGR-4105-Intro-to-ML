# %% [markdown]
# <a href="https://colab.research.google.com/github/Salitre97/ECGR-4105-Intro-to-ML/blob/main/Homework1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Problem 1 : Develop code that runs linear regreesion with a gradient descent algorithm for each of the explanatory variables in isolation. In this case we have X1, X2, X3.  Our fourth column will be Y.  I decided to use learning rate of 0.01 as it theta was smaller.

# %%
 import numpy as np
 import matplotlib.pyplot as plt
 import pandas as pd
 from google.colab import drive
 from IPython.display import display
 drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Import dataset from Google Drive
file_path = '/content/drive/My Drive/ML-4105/D3.csv'
# Read in dataset using pandas
df = pd.DataFrame(pd.read_csv(file_path))


# Seperate features and labels
X1= df.values[:, 0]  # get input values from first column -- X1 is a list here
X2 = df.values[:, 1]
X3 = df.values[:, 2]
y = df.values[:, 3]  # get ouptput values from second column -- Y is the list here
m = len(y)  # Number of training examples
n = len(X1)  # Number of training examples

iterations = 1500
alpha = 0.1

# %%
df.head()
# Out:
#          X1        X2        X3         Y
# 0  0.000000  3.440000  0.440000  4.387545
# 1  0.040404  0.134949  0.888485  2.679650
# 2  0.080808  0.829899  1.336970  2.968490
# 3  0.121212  1.524848  1.785455  3.254065
# 4  0.161616  2.219798  2.233939  3.536375

# %% [markdown]
# ***Plotting all training data and the outpot Y***

# %%
# Scatter plot

plt.scatter(X1, y, color='red', marker='+')


plt.scatter(X2, y, color='blue', marker='.')

plt.scatter(X3, y, color='green', marker='*')

# Grid, labels and title
plt.grid(True)
plt.rcParams["figure.figsize"] = (6, 6)
plt.xlabel('x1-x2-x3')
plt.ylabel('y')
plt.title('Scatter plot of training data D3.csv')

# Show the plot
plt.show()

# %% [markdown]
# ***Funciton for computing the cost and function for gradient descent***

# %%
def compute_cost(X, y, theta):
    """
    Compute cost for linear regression.

    Parameters:
    X : 2D array where each row represents the training example and each column represent the feature
        m = number of training examples
        n = number of features (including X_0 column of ones)
    y : 1D array of labels/target values for each training example. dimensions(m)
    theta : 1D array of fitting parameters or weights. Dimension (n)

    Returns:
    J : Scalar value, the cost
    """
    predictions = X.dot(theta)
    errors = np.subtract(predictions, y)
    sqrErrors = np.square(errors)
    J = 1 / (2 * m) * np.sum(sqrErrors)
    return J

def gradient_descent(X, y, theta, alpha, iterations):
    """
    Compute the optimal parameters using gradient descent for linear regression.

    Parameters:
    X : 2D array where each row represents the training example and each column represents the training exmple for each column
        m = number of training examples
        n = number of features (including X_0 column of ones)
    y : 1D array of labels/target values for each training example. dimension(m)
    theta : 1D array of fitting parameters or weights. Dimension (n)
    alpha : learning rate (scalar)
    iterations : Number of iterations (scalar)

    Returns:
    theta : Upload values fo fitting paramters or weights after 'iterations' iterations. Dimensions(n)
    cost_history : Array containing the cost for each iteration. Dimension (iteration)
    """

    m = len(y)  # Number of training examples
    cost_history = np.zeros(iterations)

    for i in range(iterations):
        predictions = X.dot(theta)
        errors = np.subtract(predictions, y)
        sum_delta = (alpha / m) * X.transpose().dot(errors)
        theta -= sum_delta
        cost_history[i] = compute_cost(X, y, theta)

    return theta, cost_history

# %%
          """---Training Model for X1---"""
# Create a column vector of ones. Will be used as the "bias" term for the linear regression
X_0 = np.ones((m, 1))

# Reshaping features (X) to make it a 2D array suitable for matrix operations
X_1 = X1.reshape(m, 1)

# Lets use hstack() function from numpy to stack X_0 and X_1 horizontally (i.e column)
# This will be our final x matrix (feature)
X = np.hstack((X_0, X_1))


# Initialize theta to zeros
theta = np.zeros(2)

# Lets compute the cosst for theta values
cost = compute_cost(X, y, theta)
print('The cost for given values of theta_0 and theta_1 =', cost)


theta = [0., 0.]



theta, cost_history = gradient_descent(X, y, theta, alpha, iterations)

print('Final value of theta =', theta)
print('cost_history =', cost_history)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-949eef90ad79> in <cell line: 3>()
#       1 """---Training Model for X1---"""
#       2 # Create a column vector of ones. Will be used as the "bias" term for the linear regression
# ----> 3 X_0 = np.ones((m, 1))
#       4
#       5 # Reshaping features (X) to make it a 2D array suitable for matrix operations
#
# NameError: name 'np' is not defined

# %%
                """---linear Regression for X1----"""
# Assuming that X, y and theta are already defined
# Also assuming that X has two columns: a feature column and a column of ones

# Scatter plot for the training data
plt.scatter(X[:, 1,], y, color='red', marker='+', label='Training Data')

# Line plot for the linear regression model
plt.plot(X[:, 1], X.dot(theta), color='green', label='Linear Regression')

# Plot customizations
plt.rcParams["figure.figsize"] = (10, 6)
plt.grid(True)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Linear Regression Fit')
plt.legend()

# Show the plot
plt.show()

# %%
          """---Convergence of gradient descent for X1----"""
plt.plot(range(1, iterations + 1), cost_history, color='blue')
plt.rcParams["figure.figsize"] = (10, 6)
plt.grid(True)

plt.xlabel('Number of iterations')
plt.ylabel('Cost (J)')
plt.title('Convergence of gradient descent')

# Show the plot
plt.show()

# %%
                            """ -----Training Model FOR X2-----"""
# Reshape X2 into a 2D array
X_2 = X2.reshape(m, 1)

X__1 = np.hstack((X_0, X_2))

theta_1 = np.zeros(2)
#theta

# Lets compute the cosst for theta values
cost_1 = compute_cost(X__1, y, theta_1)
print('The cost for given values of theta_0 and theta_1 =', cost_1)

theta_1 = [0., 0.]

theta_1, cost_history_1 = gradient_descent(X__1, y, theta_1, alpha, iterations)
print('Final value of thetat =', theta_1)
print('cost_history =', cost_history_1)

# Assuming that X, y and theta are already defined
# Also assuming that X has two columns: a feature column and a column of ones

# Scatter plot for the training data
plt.scatter(X__1[:, 1,], y, color='red', marker='+', label='Training Data')

# Line plot for the linear regression model
plt.plot(X__1[:, 1], X__1.dot(theta_1), color='green', label='Linear Regression')

# Plot customizations
plt.rcParams["figure.figsize"] = (10, 6)
plt.grid(True)
plt.xlabel('x__1')
plt.ylabel('y')
plt.title('Linear Regression Fit')
plt.legend()

# Show the plot
plt.show()
# Out:
# The cost for given values of theta_0 and theta_1 = 5.524438459196242
# Final value of thetat = [0.73606043 0.55760761]
# cost_history = [3.90731819 3.66528504 3.62832072 ... 3.59936602 3.59936602 3.59936602]

# %%
                """----Convergence for gradient descent for X2----"""
plt.plot(range(1, iterations + 1), cost_history_1, color='blue')
plt.rcParams["figure.figsize"] = (10, 6)
plt.grid(True)

plt.xlabel('Number of iterations')
plt.ylabel('Cost (J)')
plt.title('Convergence of gradient descent')

# Show the plot
plt.show()

# %%
                        """-----TRAINING MODEL FOR X3-----"""
# Reshape X2 into a 2D array
X_3 = X3.reshape(m, 1)
#
X__2 = np.hstack((X_0, X_3))

theta_2 = np.ones(2)

cost_2 = compute_cost(X__2, y, theta_2)
print('The cost for given values of theta_1 and theta_2 =', cost_2)

theta_2 = [0., 0.]

theta_2, cost_history_2 = gradient_descent(X__2, y, theta_2, alpha, iterations)
print('Final value of thetat =', theta_2)
print('cost_history =', cost_history_2)

# Assuming that X, y and theta are already defined
# Also assuming that X has two columns: a feature column and a column of ones

# Scatter plot for the training data
plt.scatter(X__2[:, 1,], y, color='red', marker='+', label='Training Data')

# Line plot for the linear regression model
plt.plot(X__2[:, 1], X__2.dot(theta), color='green', label='Linear Regression')

# Plot customizations
plt.rcParams["figure.figsize"] = (10, 6)
plt.grid(True)
plt.xlabel('x__2')
plt.ylabel('y')
plt.title('Linear Regression Fit')
plt.legend()

# Show the plot
plt.show()
# Out:
# The cost for given values of theta_1 and theta_2 = 5.791944777720338
# Final value of thetat = [ 2.8714221  -0.52048288]
# cost_history = [4.66843939 4.49602325 4.43685075 ... 3.62945112 3.62945112 3.62945112]

# %% [markdown]
# Problem 2:  We will run linear regression with gradient descent algorithm using all three explanatory variables.

# %%
              """-----Convergence of gradient descent  for X3-----"""
plt.plot(range(1, iterations + 1), cost_history_2, color='blue')
plt.rcParams["figure.figsize"] = (10, 6)
plt.grid(True)

plt.xlabel('Number of iterations')
plt.ylabel('Cost (J)')
plt.title('Convergence of gradient descent')

# Show the plot
plt.show()

# %%
                """Training Model for all Inputs X1 X2 X3"""

X__4 = np.hstack((X_0, X_1, X_2, X_3))

theta_3 = np.ones(4)

cost_3 = compute_cost(X__4, y, theta_3)
print('The cost for given values of theta 1-4 =', cost_3)

theta_3 = [0., 0., 0., 0.]


theta_3, cost_history_3 = gradient_descent(X__4, y, theta_3, alpha, iterations)
print('Final value of thetat =', theta_3)
print('cost_history =', cost_history_3)

# Assuming that X, y and theta are already defined
# Also assuming that X has two columns: a feature column and a column of ones
# Out:
# The cost for given values of theta 1-4 = 21.69679918313534
# Final value of thetat = [ 5.31416563 -2.00371905  0.53256359 -0.26560164]
# cost_history = [4.13064348 3.51770697 3.12758306 ... 0.73846424 0.73846424 0.73846424]

# %%
              """-----Convergence of gradient descent  for X__4-----"""
plt.plot(range(1, iterations + 1), cost_history_3, color='blue')
plt.rcParams["figure.figsize"] = (10, 6)
plt.grid(True)

plt.xlabel('Number of iterations')
plt.ylabel('Cost (J)')
plt.title('Convergence of gradient descent')

# Show the plot
plt.show()

# %%
                             """predictions for new inputs"""
X1_new = 1
X2_new = 1
X3_new = 1

predictions_y1 = np.array([1, X1_new]).dot(theta)
predictions_y2 = np.array([1, X2_new]).dot(theta_1)
predictions_y3 = np.array([1, X3_new]).dot(theta_2)

predictions1 = predictions_y1 + predictions_y2 + predictions_y3

print('predictions for [1, 1, 1]: ', predictions1)

X1_new = 2
X2_new = 0
X3_new = 4

predictions_y3 = np.array([1, X1_new]).dot(theta)
predictions_y1 = np.array([1, X2_new]).dot(theta_1)
predictions_y2 = np.array([1, X3_new]).dot(theta_2)

predictions2 = predictions_y1 + predictions_y2 + predictions_y3

print('predictions for [2, 0, 4]: ', predictions)


X1_new = 3
X2_new = 2
X3_new = 1

predictions_y1 = np.array([1, X1_new]).dot(theta)
predictions_y2 = np.array([1, X2_new]).dot(theta_1)
predictions_y3 = np.array([1, X3_new]).dot(theta_2)

predictions3 = predictions_y1 + predictions_y2 + predictions_y3

print('predictions for [3, 2, 1]: ', predictions3)
# Out:
# predictions for [1, 1, 1]:  7.341438987530819
# predictions for [2, 0, 4]:  2.295964981520978
# predictions for [3, 2, 1]:  3.991701133931554
